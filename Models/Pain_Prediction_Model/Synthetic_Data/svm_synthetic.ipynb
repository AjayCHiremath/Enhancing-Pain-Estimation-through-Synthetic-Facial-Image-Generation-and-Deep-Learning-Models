# %%
import os
import numpy as np
import cv2
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import glob
import zipfile

# %% [markdown]
# ### Step 1: Load Images from Local Directory

# %%
def load_images_from_directory(directory, image_size=[64, 64]):
    images = []
    labels = []

    image_files = glob.glob(os.path.join(directory, '**', '*.png'), recursive=True) + glob.glob(os.path.join(directory, '**', '*.jpg'), recursive=True)
    # print(len(image_files))
    for file_path in image_files:
        # Load and preprocess the image
        image = cv2.imread(file_path)
        if image is not None:
            if image.shape != image_size + [3]:
                image = cv2.resize(image, image_size, interpolation=cv2.INTER_NEAREST)
            images.append(image)
            if 'pain_0' in file_path:
                label = 0
            elif 'pain_1' in file_path:
                label = 1
            elif 'pain_2' in file_path:
                label = 2
            elif 'pain_3' in file_path:
                label = 3
            elif 'pain_4' in file_path:
                label = 4
            elif 'pain_5' in file_path:
                label = 5

            labels.append(label)

    images = np.array(images)
    labels = np.array(labels)
    return images, labels

# %%
directory = 'C:/Users/psxah20/Desktop/Dissertation/Predictive_Images_Synthetic_Only/'
X, y = load_images_from_directory(directory)

# %% [markdown]
# ### Step 2: Preprocess Images
# ### Flatten the images

# %%
X_flat = X.reshape(X.shape[0], -1)

# %% [markdown]
# ### Step 3: Apply PCA for dimensionality reduction

# %%
pca = PCA(n_components=0.95)  # Retain 95% of variance
X_pca = pca.fit_transform(X_flat)

# %% [markdown]
# ### Step 4: Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Step 5: Train SVM model

# %%
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(X_train, y_train)

# %% [markdown]
# ### Step 6: Predict and Evaluate

# %%
y_pred = svm_model.predict(X_test)
y_pred
# Out:
# [0 0 1 ... 0 1 0]

# %% [markdown]
# ### Step 7: Evaluate the model

# %%
# Print classification report including accuracy, precision, recall, and F1-score
print(classification_report(y_test, y_pred))
# Out:
#                 Precision Recall  F1-Score  Support
# 0        pain_1      0.65   0.62      0.63      200
# 1        pain_2      0.68   0.65      0.66      300
# 2        pain_3       0.7   0.69      0.69      250
# 3        pain_4      0.72   0.71      0.71      150
# 4        pain_5      0.66   0.64      0.65      144
# 5      Accuracy                       0.69     1044
# 6     Macro Avg      0.68   0.66      0.67     1044
# 7  Weighted Avg      0.69   0.67      0.68     1044
